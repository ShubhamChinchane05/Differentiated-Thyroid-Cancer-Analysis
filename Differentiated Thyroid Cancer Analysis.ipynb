# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Thyroid_Diff.csv")
df
# Out:
#      Age Gender Smoking Hx Smoking Hx Radiothreapy          Thyroid Function  \
# 0     27      F      No         No              No                 Euthyroid
# 1     34      F      No        Yes              No                 Euthyroid
# 2     30      F      No         No              No                 Euthyroid
# 3     62      F      No         No              No                 Euthyroid
# 4     62      F      No         No              No                 Euthyroid
# ..   ...    ...     ...        ...             ...                       ...
# 378   72      M     Yes        Yes             Yes                 Euthyroid
# 379   81      M     Yes         No             Yes                 Euthyroid
# 380   72      M     Yes        Yes              No                 Euthyroid
# 381   61      M     Yes        Yes             Yes  Clinical Hyperthyroidism
# 382   67      M     Yes         No              No                 Euthyroid
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   383 non-null    int64
#  1   Gender                383 non-null    object
#  2   Smoking               383 non-null    object
#  3   Hx Smoking            383 non-null    object
#  4   Hx Radiothreapy       383 non-null    object
#  5   Thyroid Function      383 non-null    object
#  6   Physical Examination  383 non-null    object
#  7   Adenopathy            383 non-null    object
#  8   Pathology             383 non-null    object
#  9   Focality              383 non-null    object
#  10  Risk                  383 non-null    object
#  11  T                     383 non-null    object
#  12  N                     383 non-null    object
#  13  M                     383 non-null    object
#  14  Stage                 383 non-null    object
# ...

# %%
df.describe()
# Out:
#               Age
# count  383.000000
# mean    40.866841
# std     15.134494
# min     15.000000
# 25%     29.000000
# 50%     37.000000
# 75%     51.000000
# max     82.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(19)

# %%
df.isnull().sum()
# Out:
# Age                     0
# Gender                  0
# Smoking                 0
# Hx Smoking              0
# Hx Radiothreapy         0
# Thyroid Function        0
# Physical Examination    0
# Adenopathy              0
# Pathology               0
# Focality                0
# Risk                    0
# T                       0
# N                       0
# M                       0
# Stage                   0
# Response                0
# Recurred                0
# dtype: int64

# %% [raw]
# # There are no null values in the data frame

# %%
plt.figure(figsize=(8,6))
ax = sns.countplot(x = "Gender" , data = df)
ax.bar_label(ax.containers[0])
plt.title("Gender Count")
plt.show()

# %% [raw]
# # The female count more as compared to the male

# %%
plt.figure(figsize=(8,6))
ax = sns.countplot(x = "Smoking" , data = df, hue= "Gender")
ax.bar_label(ax.containers[0])
plt.title("Smoking Count by Gender")
plt.show()

# %% [raw]
# # The majority are non-smoking females, with very few smokers overall, and a relatively higher proportion of male smokers.

# %%
plt.figure(figsize=(8,6))
ax = sns.countplot(x = "Hx Smoking" , data = df, hue= "Gender")
ax.bar_label(ax.containers[0])
plt.title("Hx Smoking Count by Gender")
plt.show()

# %% [raw]
# # The majority are non-smoking females, with very few smokers overall, and a higher proportion of male smokers.

# %%
plt.figure(figsize=(8,6))
ax = sns.countplot(x = "Hx Radiothreapy" , data = df, hue= "Gender")
ax.bar_label(ax.containers[0])
plt.title("Hx Radiothreapy Count by Gender")
plt.show()

# %% [raw]
# # The majority have no history of radiotherapy, with females being the dominant group and only a very small number having received radiotherapy.

# %%
plt.figure(figsize=(8,6))
ax = sns.countplot(y = "Thyroid Function" , data = df)
ax.bar_label(ax.containers[0])
plt.xticks(rotation = 70)
plt.title("Thyroid Function Distribution")
plt.show()

# %% [raw]
# #  The majority of individuals have normal thyroid function (euthyroid), while clinical and subclinical thyroid dysfunction cases are relatively rare.

# %%
plt.figure(figsize=(8,6))
ax = sns.countplot(y = "Adenopathy" , data = df)
ax.bar_label(ax.containers[0])
plt.xticks(rotation = 70)
plt.title("Adenopathy Distribution")
plt.show()

# %% [raw]
# # The majority of cases (277) show no adenopathy, while right-sided adenopathy is the most common among affected individuals, followed by bilateral and left-sided adenopathy.

# %%
pd.crosstab(df["Focality"], df["Stage"]).plot.pie(subplots = True, figsize = (20,20) , autopct = "%.2f%%")
plt.show()

# %%
plt.figure(figsize=(8,6))
ax = sns.countplot(x = "Focality" , data = df, hue = "Stage")
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
ax.bar_label(ax.containers[2])
ax.bar_label(ax.containers[3])
ax.bar_label(ax.containers[4])
plt.title("Focality Count")
plt.ylim(0, 250)
plt.show()

# %% [raw]
# # The count of Uni-Focal is double as compared to the Multi-Focal

# %%
plt.figure(figsize=(8,6))
ax = sns.countplot(x = "Stage" , data = df, hue="Gender")
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.title("Distribution of Cancer Stages by Gender")
plt.show()

# %% [raw]
# # The majority of cases are in Stage I, with a significantly higher number of female patients, while advanced stages (III, IVA, IVB) have relatively fewer cases.

# %%
risk_counts = df.groupby(["Thyroid Function", "Risk"]).size().unstack()
risk_counts
# Out:
# Risk                         High  Intermediate    Low
# Thyroid Function
# Clinical Hyperthyroidism      2.0           4.0   14.0
# Clinical Hypothyroidism       NaN           3.0    9.0
# Euthyroid                    28.0          88.0  216.0
# Subclinical Hyperthyroidism   NaN           NaN    5.0
# Subclinical Hypothyroidism    2.0           7.0    5.0

# %%
risk_counts.plot(kind='bar',  stacked=True, figsize=(10, 6))
plt.title("Thyroid Function vs. Risk Distribution")
plt.xlabel("Thyroid Function")
plt.ylabel("Count")
plt.show()

# %% [raw]
# # The distribution plot shows that different thyroid function categories have varying risk levels, with Euthyroid being the most common and high-risk cases concentrated in specific dysfunctions.

# %%
risk_stage_counts = df.groupby(["Thyroid Function", "Stage"]).size().unstack()
risk_stage_counts
# Out:
# Stage                            I    II  III  IVA   IVB
# Thyroid Function
# Clinical Hyperthyroidism      17.0   1.0  NaN  1.0   1.0
# Clinical Hypothyroidism       12.0   NaN  NaN  NaN   NaN
# Euthyroid                    291.0  28.0  2.0  1.0  10.0
# Subclinical Hyperthyroidism    5.0   NaN  NaN  NaN   NaN
# Subclinical Hypothyroidism     8.0   3.0  2.0  1.0   NaN

# %%
risk_stage_counts.plot(kind='bar',  stacked=True, figsize=(10, 6))
plt.title("Thyroid Function vs. Cancer Stage Distribution")
plt.xlabel("Thyroid Function")
plt.ylabel("Count")
plt.show()

# %% [raw]
# # Most cases occur in euthyroid patients, predominantly at Stage I, with very few cases in other thyroid function categories and advanced stages.

# %%
plt.figure(figsize=(12,6))
ax = sns.countplot(x = "Response" , data = df, hue= "Gender")
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.title("Response Count by Gender")
plt.show()

# %% [raw]
# # The majority of responses fall under the "Excellent" category, predominantly for females, while males have lower counts across all response categories.

# %%
plt.figure(figsize=(8,6))
ax = sns.countplot(x = "Recurred" , data = df, hue= "Gender")
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.title("Recurred Count by Gender")
plt.show()

# %% [raw]
# # Most individuals did not experience recurrence, with females having a significantly higher count in the "No" category, while recurrence is relatively lower but still more common among females than males.

# %%
plt.figure(figsize=(18,8))
ax = sns.countplot(x = "Age" , data = df, hue= "Gender")
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.title("Recurred Count by Gender")
plt.show()

# %% [raw]
# # Recurrence is more common in females across all age groups, with peaks observed in the late 20s and early 30s, whereas males show significantly lower recurrence rates in all age groups.

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='Recurred', y='Age', data=df, palette="coolwarm")
plt.title("Age-wise Recurrence Distribution")
plt.show()

# %%
fig, axes = plt.subplots(1,3, figsize=(15,5))

sns.countplot(x='T', data=df, ax=axes[0], palette="Blues")
axes[0].set_title("Tumor (T) Staging")

sns.countplot(x='N', data=df, ax=axes[1], palette="Greens")
axes[1].set_title("Lymph Node (N) Staging")

sns.countplot(x='M', data=df, ax=axes[2], palette="Reds")
axes[2].set_title("Metastasis (M) Staging")

plt.show()

# %% [raw]
# 1. Tumor (T) Staging: Most cases are in early stages (T1 & T2), suggesting early detection in many patients. However, a notable number of cases exist in advanced stages (T3 & T4), indicating delayed diagnoses.
# 2. Lymph Node (N) Involvement: A significant proportion of patients have N0 (no lymph node involvement), while some show N1 (lymph node metastasis), which is linked to higher severity.
# 3. Metastasis (M) Staging: The majority of cases are M0 (no distant metastasis), but some M1 cases indicate cancer has spread to distant organs, correlating with poor prognosis.

# %%
plt.figure(figsize=(10,6))
sns.histplot(df[df['Recurred'] == 'Yes']['Age'], bins=20, kde=True, color='red', label="Recurrence")
sns.histplot(df[df['Recurred'] == 'No']['Age'], bins=20, kde=True, color='blue', label="No Recurrence")
plt.legend()
plt.title("Age Distribution for Recurrence")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %% [raw]
# # Smoking and prior radiotherapy are associated with higher recurrence rates, indicating a potential link between these factors and disease progression. Encouraging smoking cessation and early intervention may help reduce recurrence risks.

# %%
pd.crosstab(df["Smoking"], df["Recurred"]).plot.barh()
plt.grid(axis = "x")
plt.title("Recurrence by Smoking")
plt.show()

# %% [raw]
# # The chart suggests that non-smokers have a significantly lower recurrence rate compared to smokers. Additionally, the majority of non-smokers did not experience recurrence, while smokers had a higher proportion of recurrence cases.

# %%
pd.crosstab(df["Risk"], df["Recurred"]).plot.barh()
plt.grid(axis = "x")
plt.title("Recurrence by Risk")
plt.show()

# %% [raw]
# # The chart indicates that patients with low risk have the lowest recurrence rate, while those in the intermediate and high-risk categories show a higher proportion of recurrence cases.

# %%
pd.crosstab(df["Stage"], df["Recurred"]).plot.barh()
plt.grid(axis = "x")
plt.title("Recurrence by Stage")
plt.show()

# %% [raw]
# # The chart shows that most patients are in Stage I, with a lower recurrence rate compared to higher stages. As the stage progresses (II, III, IVA, IVB), the recurrence rate increases, indicating that later-stage patients are more likely to experience recurrence.
